# %%
import research_kit_bottom_trend_follow as rk
rk.pd.set_option("display.max_columns", 250)
rk.pd.set_option("display.max_rows", 250)
import warnings
warnings.filterwarnings('ignore')

bot = rk.BottomTrendFollow(db_client=rk.mysql_client, exchange_client=rk.bitmex_exchange_client, is_backtest=True)
# Out:
# downloading BTC/USD data on bitmex
# downloading 2020-01-20 02:46:30 ~ 2020-01-20 03:54:40.084699 data
# 100.0% completed
# Loading OHLCV data from bitmex_original_ohlcv_1min now...

# %%
timeframe_params = [480,240,120,60,30,10]
bottom_trend_tick_params = [5,10,15,20,30,40,50,100]
middle_trend_tick_params = [3,5,7,9,12,18,24,30,60]
top_trend_tick_params = [1,2,3,4,8,12,20.40]

backtest_start_time = rk.datetime.now() - rk.timedelta(days=100)
backtest_end_time = rk.datetime.now()

#already finished
#rk.generate_transaction_log_by_params_combination(bot, timeframe_params, backtest_start_time, backtest_end_time,
#                                                  bottom_trend_tick_params, middle_trend_tick_params, top_trend_tick_params,
#                                                  inverse_trading=False,close_position_on_do_nothing=False,
#                                                  random_forest_leverage_adjust=False)

#rk.generate_transaction_log_by_params_combination(bot, timeframe_params, backtest_start_time, backtest_end_time,
#                                                  bottom_trend_tick_params, middle_trend_tick_params, top_trend_tick_params,
#                                                  inverse_trading=True,close_position_on_do_nothing=False,
#                                                  random_forest_leverage_adjust=False)

# %%
merged_results = rk.get_joined_params_and_summary()

timeframe_params = [480,240,120,60,30,10]

normal_results = merged_results.query("inverse_trading == False")
inversed_results = merged_results.query("inverse_trading == True")
# Out:
# data loaded

# %%
rk.profit_factor_analysis(normal_results, "Figure 1: Profit Factor For Each Timeframe", timeframe_params)

# %%
rk.profit_factor_analysis(inversed_results, "Figure 2: Profit Factor For Each Timeframe Under Inverse Trading", timeframe_params)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-dbf9eb389aa5> in <module>
# ----> 1 rk.profit_factor_analysis(inversed_results, "Figure 2: Profit Factor For Each Timeframe Under Inverse Trading", timeframe_params)
#
# ~/fintech-final/research_notebook/bottom_trend_follow/research_kit_bottom_trend_follow.py in profit_factor_analysis(df, figure_title, timeframe_params)
#     312     for i, timeframe in enumerate(timeframe_params):
#     313         profit_factor_histogram = fig_profit_factor_histogram.add_subplot(len(timeframe_params) + 1,1, 2 + i)
# --> 314         profit_factor_histogram.hist(columns_picked_up.query("timeframe==" + str(timeframe)).profit_factor, bins=bins)
#     315         profit_factor_histogram.set_title("profit factor distribution for timeframe=" + str(timeframe))
#     316         profit_factor_histogram.set_xlabel("profit factor")
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6765             # this will automatically overwrite bins,
#    6766             # so that each histogram uses the same bins
# -> 6767             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6768             m = m.astype(float)  # causes problems later if it's an int
#    6769             if mlast is None:
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     783     a, weights = _ravel_and_check_weights(a, weights)
#     784
# --> 785     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     786
#     787     # Histogram is an integer or a float array depending on the weights.
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     417             raise ValueError('`bins` must be positive, when an integer')
#     418
# --> 419         first_edge, last_edge = _get_outer_edges(a, range)
#     420
#     421     elif np.ndim(bins) == 1:
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/numpy/lib/histograms.py in _get_outer_edges(a, range)
#     315         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#     316             raise ValueError(
# --> 317                 "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#     318
#     319     # expand empty range to avoid divide by zero
#
# ValueError: autodetected range of [nan, nan] is not finite

# %%
rk.visualize_timeframe_entry_profit_relation(normal_results,
    "Figure 3: Total Return and Total Entry Relationship for each timeframe", timeframe_params)

# %%
rk.visualize_timeframe_entry_profit_relation(inversed_results,
    "Figure 4: Total Return and Total Entry Relationship for Each Timeframe on Inverse Trading", timeframe_params)

# %%
rk.find_optimal_parameters_by_ranking(normal_results, timeframe_params, bottom_trend_tick_params, middle_trend_tick_params,
                                      top_trend_tick_params, verbose=False)
rk.find_optimal_parameters_by_ranking(inversed_results, timeframe_params, bottom_trend_tick_params, middle_trend_tick_params,
                                      top_trend_tick_params, verbose=False)
# Out:
# calc optimal parameters for timeframe:60
# optimal bottom => 5 middle => 3top => 1
# calc optimal parameters for timeframe:30
# optimal bottom => 5 middle => 3top => 1
# calc optimal parameters for timeframe:10
# optimal bottom => 5 middle => 3top => 1
# calc optimal parameters for timeframe:1
# optimal bottom => 5 middle => 3top => 1
# calc optimal parameters for timeframe:60
# optimal bottom => 5 middle => 3top => 1
# calc optimal parameters for timeframe:30
# optimal bottom => 5 middle => 3top => 1
# calc optimal parameters for timeframe:10
# optimal bottom => 5 middle => 3top => 1
# calc optimal parameters for timeframe:1
# optimal bottom => 5 middle => 3top => 1
